# %% [markdown]
# # Analytics

# %% [markdown]
# #### Date: 2020/05
#
# #### SUMMARY:
#
# - This notebook represents the project quality analysis of the date exposed right above.

# %% [markdown]
# ### TEAM:
#
# ##### Semester: 2020/02
# ##### Professor: Hilmer Neri
#
# ##### Members:
#
# - Arthur Matos
# - Brian Pina
# - Gabriel Sabanai
# - Guilherme Marques
# - Luiz Henrique Zamprogno
# - Luiz Pettengill
# - Matheus Blanco
# - Pedro Féo
# - Saleh Kader
# - Victor Buendia

# %% [markdown]
# ### LIBRARIES

# %%
# Deal with data
import pandas as pd
import numpy as np
import json
from glob import glob
import os

# Deal with API request
import urllib3
from urllib3 import request

# Deal with visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### GRAPH SETTINGS

# %%
# %config InlineBackend.figure_format ='retina'
sns.set(font_scale=1.5)
sns.set_style('darkgrid',
              {'xtick.bottom' : True,
               'ytick.left': True,
               'grid.linestyle':'--',
               'font.monospace': ['Computer Modern Typewriter'],
               'axes.edgecolor' : 'white'})

# %% [markdown]
# ### DATAFRAME SETTINGS

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ### SonarCloud

# %%
repos = [
    'Eccoar_Complaint',
    'eccoar_frontend',
    'Eccoar_Gateway',
    'Eccoar_Mailer',
    'Eccoar_Reports',
    'Eccoar_Users'
]

language = [['Eccoar_Complaint', 'ts'], 
            ['eccoar_frontend', 'ts'], 
            ['Eccoar_Gateway', 'ts'], 
            ['Eccoar_Mailer', 'ts'], 
            ['Eccoar_Reports', 'ts'], 
            ['Eccoar_Users', 'ts']]

repos_lenguage = {}

for item in language:
    repos_lenguage[f"{item[0]}"] = item[1]

# %%
repos_lenguage
# Out:
# {'Eccoar_Complaint': 'ts',
#  'eccoar_frontend': 'ts',
#  'Eccoar_Gateway': 'ts',
#  'Eccoar_Mailer': 'ts',
#  'Eccoar_Reports': 'ts',
#  'Eccoar_Users': 'ts'}

# %% [markdown]
# ##### Path to the folder with all your jsons

# %%
jsons = glob('**/*.json') # add the path here

# %%
def read_json(json_path):
    
    with open(json_path) as json_file:
        json_obj = json.load(json_file)
        
    return json_obj

def create_base_component_df(json_list):
    
    df = pd.DataFrame()

    for i in json_list:

        base_component = read_json(i)

        base_component_data = base_component['baseComponent']['measures']

        base_component_df = pd.DataFrame(base_component_data)

        base_component_df['filename'] = os.path.basename(i)

        df = df.append(base_component_df, ignore_index=True)

    
    aux_df = df['filename'].str.split(r"fga-eps-mds-2020_2-(.*?)-(.*?).json", expand=True)
    
    df['repository'] = aux_df[1]
    
    df['version'] = aux_df[2]
    
    df = df.sort_values(by=['repository', 'version'])
        
    return df, repos

# %% [markdown]
# #### Create base component dataframe

# %%
base_component_df, repos = create_base_component_df(jsons)

# %%
base_component_df.head(10)
# Out:
#                        metric value bestValue  \
# 108  duplicated_lines_density   0.0      True
# 109                 functions    42       NaN
# 110       test_execution_time    70       NaN
# 111           security_rating   1.0      True
# 112                     tests    21       NaN
# 113                     files    19       NaN
# 114                complexity    60       NaN
# 115                     ncloc   626       NaN
# 116                  coverage  68.2     False
# 117        reliability_rating   1.0      True
#
#                                               filename        repository  \
# 108  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...  Eccoar_Complaint
# 109  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...  Eccoar_Complaint
# 110  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...  Eccoar_Complaint
# 111  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...  Eccoar_Complaint
# 112  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...  Eccoar_Complaint
# 113  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...  Eccoar_Complaint
# 114  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...  Eccoar_Complaint
# 115  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...  Eccoar_Complaint
# 116  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...  Eccoar_Complaint
# 117  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...  Eccoar_Complaint
#
#         version
# 108  01-05-2021
# 109  01-05-2021
# 110  01-05-2021
# 111  01-05-2021
# 112  01-05-2021
# 113  01-05-2021
# 114  01-05-2021
# 115  01-05-2021
# 116  01-05-2021
# 117  01-05-2021

# %% [markdown]
# #### Create dataframe per file

# %%
metric_list = ['files',
               'functions',
               'complexity',
               'comment_lines_density',
               'duplicated_lines_density',
               'coverage',
               'ncloc',
               'security_rating',
               'tests',
               'test_success_density',
               'test_execution_time',
               'reliability_rating']

len(metric_list)
# Out:
# 12

# %%
def metric_per_file(json):
    
    file_json = []
    
    for component in json['components']:
        if component['qualifier'] == 'FIL':
            file_json.append(component)
            
    return file_json

def generate_file_dataframe_per_release(metric_list, json, language_extension):
    
    df_columns = metric_list
    df = pd.DataFrame(columns = df_columns)
    
    for file in json:
        try:
            if file['language'] == language_extension:
                for measure in file['measures']:
                    df.at[file['path'], measure['metric']] = measure['value']
        except:
            pass
        
    df.reset_index(inplace = True)
    df = df.rename({'index': 'path'}, axis=1).drop(['files'], axis=1)

    return df

def create_file_df(json_list):
    
    df = pd.DataFrame()

    for i in json_list:

        file_component = read_json(i)
        
        file_component_data = metric_per_file(file_component)

        file_component_df = generate_file_dataframe_per_release(metric_list, file_component_data, language_extension = 'ts')

        file_component_df['filename'] = os.path.basename(i)

        df = df.append(file_component_df, ignore_index=True)
        
    # replace TeamName by yours.    
    aux_df = df['filename'].str.split(r"fga-eps-mds-2020_2-(.*?)-(.*?).json", expand=True)
    
    df['repository'] = aux_df[1]
    
    df['version'] = aux_df[2]
    
    df = df.sort_values(by=['repository', 'version'])
        
    return df

# %%
file_component_df = create_file_df(jsons)

# %%
file_component_df.head(10)
# Out:
#                                                path functions complexity  \
# 111  src/migration/1618526567509-CreateComplaint.ts         2          2
# 112       src/migration/1618529825437-CreateVote.ts         2          2
# 113                           src/utils/Category.ts         0          0
# 114                         src/entity/Complaint.ts         0          0
# 115         src/repositories/ComplaintRepository.ts         7          7
# 116                    src/utils/ComplaintUpvote.ts         1          3
# 117                      src/utils/ComplaintVote.ts         0          0
# 118             src/utils/ComplaintVoteConfirmed.ts         1          3
# 119                  src/utils/ComplaintWithVote.ts         0          0
# 120          src/controllers/ControllerComplaint.ts        13         24
#
#     comment_lines_density duplicated_lines_density coverage ncloc  \
# 111                   0.0                      0.0      0.0    76
# 112                   0.0                      0.0      0.0    38
# 113                   0.0                      0.0    100.0     5
# 114                   0.0                      0.0    100.0    36
# 115                   0.0                      0.0     61.3    80
# 116                   0.0                      0.0     63.6    16
# 117                   0.0                      0.0      NaN     9
# 118                   0.0                      0.0     92.3    18
# 119                   0.0                      0.0      NaN    18
# 120                   0.0                      0.0     90.3   170
#
#     security_rating tests test_success_density test_execution_time  \
# 111             1.0   NaN                100.0                 NaN
# 112             1.0   NaN                100.0                 NaN
# 113             1.0   NaN                100.0                 NaN
# 114             1.0   NaN                100.0                 NaN
# 115             1.0   NaN                100.0                 NaN
# 116             1.0   NaN                100.0                 NaN
# 117             1.0   NaN                100.0                 NaN
# 118             1.0   NaN                100.0                 NaN
# 119             1.0   NaN                100.0                 NaN
# 120             1.0   NaN                100.0                 NaN
#
#     reliability_rating                                           filename  \
# 111                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 112                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 113                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 114                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 115                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 116                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 117                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 118                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 119                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 120                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
#
#            repository     version
# 111  Eccoar_Complaint  01-05-2021
# 112  Eccoar_Complaint  01-05-2021
# 113  Eccoar_Complaint  01-05-2021
# 114  Eccoar_Complaint  01-05-2021
# 115  Eccoar_Complaint  01-05-2021
# 116  Eccoar_Complaint  01-05-2021
# 117  Eccoar_Complaint  01-05-2021
# 118  Eccoar_Complaint  01-05-2021
# 119  Eccoar_Complaint  01-05-2021
# 120  Eccoar_Complaint  01-05-2021

# %%
file_component_df.to_excel('data.xlsx', index = False)

# %%
file_component_df.repository.unique()
# Out:
# array(['Eccoar_Complaint', 'Eccoar_Gateway', 'Eccoar_Mailer',
#        'Eccoar_Reports', 'Eccoar_Users', 'eccoar_frontend'], dtype=object)

# %% [markdown]
# #### Create dataframe per repository

# %%
repository_dataframes = {} 

for repository in repos:
    df = file_component_df[file_component_df['repository'] == f"{repository}"]
    df.name = f"{repository}"
    repository_dataframes[f"{repository}"] = df
    
repository_dataframes.keys()
# Out:
# dict_keys(['Eccoar_Complaint', 'eccoar_frontend', 'Eccoar_Gateway', 'Eccoar_Mailer', 'Eccoar_Reports', 'Eccoar_Users'])

# %%
repository_dataframes["Eccoar_Complaint"]
# Out:
#    1.0   NaN                100.0                 NaN
# 66              1.0   NaN                100.0                 NaN
# 67              1.0   NaN                100.0                 NaN
# 68              1.0   NaN                100.0                 NaN
# 69              1.0   NaN                100.0                 NaN
#
#     reliability_rating                                           filename  \
# 111                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 112                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 113                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 114                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 115                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 116                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 117                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 118                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 119                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 120                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 121                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 122                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 123                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 124                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 125                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 126                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 127                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 128                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 129                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-01-05-2021...
# 130                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 131                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 132                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 133                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 134                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 135                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 136                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 137                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 138                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 139                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 140                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 141                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 142                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 143                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 144                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 145                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 146                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 147                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 148                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-03-05-2021...
# 166                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 167                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 168                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 169                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 170                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 171                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 172                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 173                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 174                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 175                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 176                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 177                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 178                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 179                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 180                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 181                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 182                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 183                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 184                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 185                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-05-05-2021...
# 70                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 71                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 72                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 73                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 74                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 75                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 76                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 77                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 78                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 79                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 80                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 81                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 82                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 83                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 84                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 85                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 86                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 87                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 88                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 89                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-10-05-2021...
# 201                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 202                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 203                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 204                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 205                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 206                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 207                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 208                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 209                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 210                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 211                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 212                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 213                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 214                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 215                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-12-04-2021...
# 186                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 187                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 188                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 189                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 190                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 191                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 192                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 193                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 194                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 195                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 196                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 197                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 198                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 199                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 200                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-04-2021...
# 90                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 91                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 92                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 93                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 94                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 95                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 96                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 97                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 98                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 99                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 100                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 101                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 102                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 103                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 104                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 105                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 106                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 107                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 108                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 109                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 110                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-17-05-2021...
# 149                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 150                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 151                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 152                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 153                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 154                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 155                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 156                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 157                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 158                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 159                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 160                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 161                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 162                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 163                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 164                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 165                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-21-04-2021...
# 216                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-23-03-2021...
# 217                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-23-03-2021...
# 218                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-23-03-2021...
# 219                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-23-03-2021...
# 220                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-23-03-2021...
# 221                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-23-03-2021...
# 222                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-23-03-2021...
# 223                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-23-03-2021...
# 224                1.0  fga-eps-mds-2020_2-Eccoar_Complaint-23-03-2021...
# 52                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 53                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 54                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 55                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 56                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 57                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 58                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 59                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 60                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 61                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 62                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 63                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 64                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 65                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 66                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 67                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 68                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
# 69                 1.0  fga-eps-mds-2020_2-Eccoar_Complaint-27-04-2021...
#
#            repository     version
# 111  Eccoar_Complaint  01-05-2021
# 112  Eccoar_Complaint  01-05-2021
# 113  Eccoar_Complaint  01-05-2021
# 114  Eccoar_Complaint  01-05-2021
# 115  Eccoar_Complaint  01-05-2021
# 116  Eccoar_Complaint  01-05-2021
# 117  Eccoar_Complaint  01-05-2021
# 218  Eccoar_Complaint  23-03-2021
# 219  Eccoar_Complaint  23-03-2021
# 220  Eccoar_Complaint  23-03-2021
# 221  Eccoar_Complaint  23-03-2021
# 222  Eccoar_Complaint  23-03-2021
# 223  Eccoar_Complaint  23-03-2021
# 224  Eccoar_Complaint  23-03-2021
# 52   Eccoar_Complaint  27-04-2021
# 53   Eccoar_Complaint  27-04-2021
# 54   Eccoar_Complaint  27-04-2021
# 55   Eccoar_Complaint  27-04-2021
# 56   Eccoar_Complaint  27-04-2021
# 57   Eccoar_Complaint  27-04-2021
# 58   Eccoar_Complaint  27-04-2021
# 59   Eccoar_Complaint  27-04-2021
# 60   Eccoar_Complaint  27-04-2021
# 61   Eccoar_Complaint  27-04-2021
# 62   Eccoar_Complaint  27-04-2021
# 63   Eccoar_Complaint  27-04-2021
# 64   Eccoar_Complaint  27-04-2021
# 65   Eccoar_Complaint  27-04-2021
# 66   Eccoar_Complaint  27-04-2021
# 67   Eccoar_Complaint  27-04-2021
# 68   Eccoar_Complaint  27-04-2021
# 69   Eccoar_Complaint  27-04-2021

# %% [markdown]
# ### Metric calculations

# %% [markdown]
# ##### COMPLEXITY

# %%
def m1(df):
    
    density_non_complex_files = len(df[(df['complexity'].astype(float)/df['functions'].astype(float)) < 10])/len(df)
    
    return density_non_complex_files

# %% [markdown]
# ##### COMMENTS

# %%
def m2(df):
    
    density_comment_files = len(df[(df['comment_lines_density'].astype(float) > 10) & (df['comment_lines_density'].astype(float) < 30)])/len(df)
    
    return density_comment_files

# %% [markdown]
# ##### DUPLICATIONS

# %%
def m3(df):
    
    duplication = len(df[(df['duplicated_lines_density'].astype(float) < 5)])/len(df)
    
    return duplication

# %% [markdown]
# ### Calculate m1, m2 and m3 for each repository

# %%
def create_metrics_df(df):
    
    version_vec = df['version'].unique()
    
    m1_list = []
    m2_list = []
    m3_list = []
    repository_list = []
    version_list = []
    
    metrics_df = pd.DataFrame()
    
    for version in version_vec:

        version_df = df[df['version'] == version]

        m1_list.append(m1(version_df))
        m2_list.append(m2(version_df))
        m3_list.append(m3(version_df))
        repository_list.append(version_df['repository'].iloc[0])
        version_list.append(version)
        
    metrics_df = pd.DataFrame({'m1': m1_list,
                               'm2': m2_list,
                               'm3': m3_list,
                               'repository': repository_list, 
                               'version': version_list})
        
    return metrics_df

# %%
repository_metrics = {}

for repository, repo_df in repository_dataframes.items():   
    metrics_df = create_metrics_df(repo_df)
    metrics_df.name = f"{repository}"
    repository_metrics[f"{repository}"] = metrics_df

# %% [markdown]
# ### Data visualization
#
# - You must do this for each of your repositories

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:COMPLEXITY")
    plt.plot(metrics_df['m1'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ## Comments
#
# ### Os dados coletados a partir das métricas relacionadas

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:COMMENTS")
    plt.plot(metrics_df['m2'], linewidth=3, marker='o', markersize=10)

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:DUPLICATIONS")
    plt.plot(metrics_df['m3'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ### Sub characteristic aggregation
#
# - You must do this for each of your repositories

# %%
psc1 = 1
pm1 = 0.33
pm2 = 0.33
pm3 = 0.33

for repository, metrics_df in repository_metrics.items(): 
    metrics_df['asc1'] = ((metrics_df['m1']*pm1)+(metrics_df['m2']*pm2)+(metrics_df['m3']*pm3))*psc1

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:asc1")
    plt.plot(metrics_df['asc1'], linewidth=3, marker='o', markersize=10)

# %%
all_metrics_df = pd.DataFrame()

for repository, metrics_df in repository_metrics.items():
    all_metrics_df = pd.concat([all_metrics_df, metrics_df], ignore_index=True)

all_metrics_df['ac1'] = all_metrics_df['asc1'] * 1
all_metrics_df['total'] = all_metrics_df['asc1'] * 1

# %%
all_metrics_df
# Out:
#           m1        m2   m3        repository     version      asc1       ac1  \
# 0   0.578947  0.000000  1.0  Eccoar_Complaint  01-05-2021  0.521053  0.521053
# 1   0.578947  0.000000  1.0  Eccoar_Complaint  03-05-2021  0.521053  0.521053
# 2   0.700000  0.000000  1.0  Eccoar_Complaint  05-05-2021  0.561000  0.561000
# 3   0.700000  0.000000  1.0  Eccoar_Complaint  10-05-2021  0.561000  0.561000
# 4   0.533333  0.000000  1.0  Eccoar_Complaint  12-04-2021  0.506000  0.506000
# 5   0.533333  0.000000  1.0  Eccoar_Complaint  17-04-2021  0.506000  0.506000
# 6   0.666667  0.000000  1.0  Eccoar_Complaint  17-05-2021  0.550000  0.550000
# 7   0.588235  0.000000  1.0  Eccoar_Complaint  21-04-2021  0.524118  0.524118
# 8   0.666667  0.000000  1.0  Eccoar_Complaint  23-03-2021  0.550000  0.550000
# 9   0.555556  0.000000  1.0  Eccoar_Complaint  27-04-2021  0.513333  0.513333
# 10  0.906250  0.031250  1.0   eccoar_frontend  03-05-2021  0.639375  0.639375
# 11  0.906250  0.031250  1.0   eccoar_frontend  08-05-2021  0.639375  0.639375
# 12  0.906250  0.031250  1.0   eccoar_frontend  10-05-2021  0.639375  0.639375
# 13  0.875000  0.041667  1.0   eccoar_frontend  12-04-2021  0.632500  0.632500
# 14  0.875000  0.041667  1.0   eccoar_frontend  17-04-2021  0.632500  0.632500
# 15  0.911765  0.029412  1.0   eccoar_frontend  17-05-2021  0.640588  0.640588
# 16  0.875000  0.041667  1.0   eccoar_frontend  21-04-2021  0.632500  0.632500
# 17  0.850000  0.050000  1.0   eccoar_frontend  23-03-2021  0.627000  0.627000
# 18  0.888889  0.037037  1.0   eccoar_frontend  23-04-2021  0.635556  0.635556
# 19  0.888889  0.037037  1.0   eccoar_frontend  26-04-2021  0.635556  0.635556
# 20  0.906250  0.031250  1.0   eccoar_frontend  27-04-2021  0.639375  0.639375
# 21  0.875000  0.000000  1.0    Eccoar_Gateway  01-05-2021  0.618750  0.618750
# 22  0.875000  0.000000  1.0    Eccoar_Gateway  03-05-2021  0.618750  0.618750
# 23  0.875000  0.000000  1.0    Eccoar_Gateway  05-05-2021  0.618750  0.618750
# 24  0.875000  0.000000  1.0    Eccoar_Gateway  10-05-2021  0.618750  0.618750
# 25  1.000000  0.000000  1.0    Eccoar_Gateway  12-04-2021  0.660000  0.660000
# 26  1.000000  0.000000  1.0    Eccoar_Gateway  17-04-2021  0.660000  0.660000
# 27  0.909091  0.000000  1.0    Eccoar_Gateway  17-05-2021  0.630000  0.630000
# 28  1.000000  0.000000  1.0    Eccoar_Gateway  23-03-2021  0.660000  0.660000
# 29  1.000000  0.000000  1.0    Eccoar_Gateway  23-04-2021  0.660000  0.660000
# 30  0.875000  0.000000  1.0    Eccoar_Gateway  28-04-2021  0.618750  0.618750
# 31  0.600000  0.000000  1.0     Eccoar_Mailer  03-05-2021  0.528000  0.528000
# 32  0.666667  0.000000  1.0     Eccoar_Mailer  12-04-2021  0.550000  0.550000
# 33  0.666667  0.000000  1.0     Eccoar_Mailer  17-04-2021  0.550000  0.550000
# 34  0.600000  0.000000  1.0     Eccoar_Mailer  17-05-2021  0.528000  0.528000
# 35  0.666667  0.000000  1.0     Eccoar_Mailer  22-04-2021  0.550000  0.550000
# 36  0.714286  0.000000  1.0     Eccoar_Mailer  23-03-2021  0.565714  0.565714
# 37  0.666667  0.000000  1.0     Eccoar_Mailer  23-04-2021  0.550000  0.550000
# 38  0.600000  0.000000  1.0     Eccoar_Mailer  27-04-2021  0.528000  0.528000
# 39  0.700000  0.000000  1.0    Eccoar_Reports  03-05-2021  0.561000  0.561000
# 40  0.777778  0.000000  1.0    Eccoar_Reports  12-04-2021  0.586667  0.586667
# 41  0.777778  0.000000  1.0    Eccoar_Reports  17-04-2021  0.586667  0.586667
# 42  0.700000  0.000000  1.0    Eccoar_Reports  17-05-2021  0.561000  0.561000
# 43  1.000000  0.000000  1.0    Eccoar_Reports  23-03-2021  0.660000  0.660000
# 44  0.700000  0.000000  1.0    Eccoar_Reports  27-04-2021  0.561000  0.561000
# 45  0.666667  0.000000  1.0      Eccoar_Users  03-05-2021  0.550000  0.550000
# 46  0.666667  0.000000  1.0      Eccoar_Users  10-05-2021  0.550000  0.550000
# 47  1.000000  0.000000  1.0      Eccoar_Users  12-04-2021  0.660000  0.660000
# 48  0.666667  0.000000  1.0      Eccoar_Users  17-05-2021  0.550000  0.550000
# 49  1.000000  0.000000  1.0      Eccoar_Users  23-03-2021  0.660000  0.660000
# 50  0.666667  0.000000  1.0      Eccoar_Users  23-04-2021  0.550000  0.550000
#
#        total
# 0   0.521053
# 1   0.521053
# 2   0.561000
# 3   0.561000
# 4   0.506000
# 5   0.506000
# 6   0.550000
# 7   0.524118
# 8   0.550000
# 9   0.513333
# 10  0.639375
# 11  0.639375
# 12  0.639375
# 13  0.632500
# 14  0.632500
# 15  0.640588
# 16  0.632500
# 17  0.627000
# 18  0.635556
# 19  0.635556
# 20  0.639375
# 21  0.618750
# 22  0.618750
# 23  0.618750
# 24  0.618750
# 25  0.660000
# 26  0.660000
# 27  0.630000
# 28  0.660000
# 29  0.660000
# 30  0.618750
# 31  0.528000
# 32  0.550000
# 33  0.550000
# 34  0.528000
# 35  0.550000
# 36  0.565714
# 37  0.550000
# 38  0.528000
# 39  0.561000
# 40  0.586667
# 41  0.586667
# 42  0.561000
# 43  0.660000
# 44  0.561000
# 45  0.550000
# 46  0.550000
# 47  0.660000
# 48  0.550000
# 49  0.660000
# 50  0.550000

# %%
metrics_df.to_excel('metrics_df.xlsx', index = False)
